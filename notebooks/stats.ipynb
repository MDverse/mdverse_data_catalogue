# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %load_ext watermark
# %watermark --python --machine
# Python packages versions
# %watermark --packages jupyterlab --iversions --watermark
# Out:
# Python implementation: CPython
# Python version       : 3.12.3
# IPython version      : 9.10.0
#
# Compiler    : GCC 13.3.0
# OS          : Linux
# Release     : 6.17.0-19-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 14
# Architecture: 64bit
#
# jupyterlab: 4.5.4
#
# matplotlib: 3.10.8
# numpy     : 2.4.2
# pandas    : 2.3.3
#
# Watermark: 2.6.0

# %%
# %load_ext autoreload
# %autoreload 2

from mdverse.scrapers import stats

# %%
parquet_files = stats.list_parquet_files(
    [
        "../data/zenodo/2026-02-16",
        "../data/figshare/2026-03-10",
        "../data/mddb/2026-02-18",
        "../data/nomad/2026-02-18",
        "../data/atlas/2026-02-18",
        "../data/gpcrmd/2026-02-18",
    ]
)
datasets_df, files_df = stats.read_datasets_files_dataframes(parquet_files)
# Out:
# Reading data from: ../data/zenodo/2026-02-16/zenodo_datasets.parquet
# Adding 2,373 datasets
# Reading data from: ../data/zenodo/2026-02-16/zenodo_files.parquet
# Adding 506,320 files
# Reading data from: ../data/figshare/2026-03-10/figshare_datasets.parquet
# Adding 1,373 datasets
# Reading data from: ../data/figshare/2026-03-10/figshare_files.parquet
# Adding 223,928 files
# Reading data from: ../data/mddb/2026-02-18/mddb_datasets.parquet
# Adding 5,079 datasets
# Reading data from: ../data/mddb/2026-02-18/mddb_files.parquet
# Adding 849,967 files
# Reading data from: ../data/nomad/2026-02-18/nomad_datasets.parquet
# Adding 16,119 datasets
# Reading data from: ../data/nomad/2026-02-18/nomad_files.parquet
# Adding 555,990 files
# Reading data from: ../data/atlas/2026-02-18/atlas_files.parquet
# Adding 5,814 files
# Reading data from: ../data/atlas/2026-02-18/atlas_datasets.parquet
# Adding 1,938 datasets
# Reading data from: ../data/gpcrmd/2026-02-18/gpcrmd_files.parquet
# Adding 2,414 files
# Reading data from: ../data/gpcrmd/2026-02-18/gpcrmd_datasets.parquet
# Adding 830 datasets

# %%
# Aggregate datasets
datasets_agg = stats.aggregate_datasets(datasets_df)
datasets_agg
# Out:
#                          number_of_datasets date_first_dataset  \
# dataset_repository_name
# atlas                                  1938                NaN
# figshare                               1373         2012-08-20
# gpcrmd                                  830         2017-03-23
# mdposit_cineca_node                     310         2025-06-20
# mdposit_inria_node                      719         2025-06-19
# mdposit_mmb_node                       4050         2025-06-18
# nomad                                 16119         2021-05-13
# zenodo                                 2369         2014-11-19
#
#                         date_last_dataset
# dataset_repository_name
# atlas                                 NaN
# figshare                       2026-03-09
# gpcrmd                         2025-10-30
# mdposit_cineca_node            2025-11-10
# mdposit_inria_node             2025-11-06
# mdposit_mmb_node               2026-02-10
# nomad                          2026-02-05
# zenodo                         2026-02-14

# %%
# Aggregate files
files_agg = stats.aggregate_files(files_df)
files_agg
# Out:
#                          number_of_datasets  deposited_files  \
# dataset_repository_name
# atlas                                  1938             5814
# figshare                               1373             8419
# gpcrmd                                  432             2414
# mdposit_cineca_node                     310           251583
# mdposit_inria_node                      719           186293
# mdposit_mmb_node                       4050           412091
# nomad                                 16115           555990
# zenodo                                 2370            36019
#
#                          deposited_zip_files  deposited_file_size_in_GB  \
# dataset_repository_name
# atlas                                   5814               10362.700600
# figshare                                1026                1216.186979
# gpcrmd                                    25                 623.758935
# mdposit_cineca_node                        0                  51.571834
# mdposit_inria_node                         0                1021.540981
# mdposit_mmb_node                           0               15123.717498
# nomad                                      0                2188.822289
# zenodo                                  4893               26686.658247
#
#                          total_number_of_files
# dataset_repository_name
# atlas                                     5814
# figshare                                223928
# gpcrmd                                    2414
# mdposit_cineca_node                     251583
# mdposit_inria_node                      186293
# mdposit_mmb_node                        412091
# nomad                                   555990
# zenodo                                  506320

# %%
merged_df = (pd.merge(datasets_agg, files_agg, how="inner", on=["dataset_repository_name"], suffixes=("_from_datasets", "_from_files")))
merged_df.loc["total"] = merged_df.sum(numeric_only=True)
merged_df.style.format(thousands=",", precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5d4b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d4b2_level0_col0" class="col_heading level0 col0" >number_of_datasets_from_datasets</th>
#       <th id="T_5d4b2_level0_col1" class="col_heading level0 col1" >date_first_dataset</th>
#       <th id="T_5d4b2_level0_col2" class="col_heading level0 col2" >date_last_dataset</th>
#       <th id="T_5d4b2_level0_col3" class="col_heading level0 col3" >number_of_datasets_from_files</th>
#       <th id="T_5d4b2_level0_col4" class="col_heading level0 col4" >deposited_files</th>
#       <th id="T_5d4b2_level0_col5" class="col_heading level0 col5" >deposited_zip_files</th>
#       <th id="T_5d4b2_level0_col6" class="col_heading level0 col6" >deposited_file_size_in_GB</th>
#       <th id="T_5d4b2_level0_col7" class="col_heading level0 col7" >total_number_of_files</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset_repository_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d4b2_level0_row0" class="row_heading level0 row0" >atlas</th>
#       <td id="T_5d4b2_row0_col0" class="data row0 col0" >1,938</td>
#       <td id="T_5d4b2_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_5d4b2_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_5d4b2_row0_col3" class="data row0 col3" >1,938</td>
#       <td id="T_5d4b2_row0_col4" class="data row0 col4" >5,814</td>
#       <td id="T_5d4b2_row0_col5" class="data row0 col5" >5,814</td>
#       <td id="T_5d4b2_row0_col6" class="data row0 col6" >10,363</td>
#       <td id="T_5d4b2_row0_col7" class="data row0 col7" >5,814</td>
#     </tr>
#     <tr>
#       <th id="T_5d4b2_level0_row1" class="row_heading level0 row1" >figshare</th>
#       <td id="T_5d4b2_row1_col0" class="data row1 col0" >1,373</td>
#       <td id="T_5d4b2_row1_col1" class="data row1 col1" >2012-08-20</td>
#       <td id="T_5d4b2_row1_col2" class="data row1 col2" >2026-03-09</td>
#       <td id="T_5d4b2_row1_col3" class="data row1 col3" >1,373</td>
#       <td id="T_5d4b2_row1_col4" class="data row1 col4" >8,419</td>
#       <td id="T_5d4b2_row1_col5" class="data row1 col5" >1,026</td>
#       <td id="T_5d4b2_row1_col6" class="data row1 col6" >1,216</td>
#       <td id="T_5d4b2_row1_col7" class="data row1 col7" >223,928</td>
#     </tr>
#     <tr>
#       <th id="T_5d4b2_level0_row2" class="row_heading level0 row2" >gpcrmd</th>
#       <td id="T_5d4b2_row2_col0" class="data row2 col0" >830</td>
#       <td id="T_5d4b2_row2_col1" class="data row2 col1" >2017-03-23</td>
#       <td id="T_5d4b2_row2_col2" class="data row2 col2" >2025-10-30</td>
#       <td id="T_5d4b2_row2_col3" class="data row2 col3" >432</td>
#       <td id="T_5d4b2_row2_col4" class="data row2 col4" >2,414</td>
#       <td id="T_5d4b2_row2_col5" class="data row2 col5" >25</td>
#       <td id="T_5d4b2_row2_col6" class="data row2 col6" >624</td>
#       <td id="T_5d4b2_row2_col7" class="data row2 col7" >2,414</td>
#     </tr>
#     <tr>
#       <th id="T_5d4b2_level0_row3" class="row_heading level0 row3" >mdposit_cineca_node</th>
#       <td id="T_5d4b2_row3_col0" class="data row3 col0" >310</td>
#       <td id="T_5d4b2_row3_col1" class="data row3 col1" >2025-06-20</td>
#       <td id="T_5d4b2_row3_col2" class="data row3 col2" >2025-11-10</td>
#       <td id="T_5d4b2_row3_col3" class="data row3 col3" >310</td>
#       <td id="T_5d4b2_row3_col4" class="data row3 col4" >251,583</td>
#       <td id="T_5d4b2_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_5d4b2_row3_col6" class="data row3 col6" >52</td>
#       <td id="T_5d4b2_row3_col7" class="data row3 col7" >251,583</td>
#     </tr>
#     <tr>
#       <th id="T_5d4b2_level0_row4" class="row_heading level0 row4" >mdposit_inria_node</th>
#       <td id="T_5d4b2_row4_col0" class="data row4 col0" >719</td>
#       <td id="T_5d4b2_row4_col1" class="data row4 col1" >2025-06-19</td>
#       <td id="T_5d4b2_row4_col2" class="data row4 col2" >2025-11-06</td>
#       <td id="T_5d4b2_row4_col3" class="data row4 col3" >719</td>
#       <td id="T_5d4b2_row4_col4" class="data row4 col4" >186,293</td>
#       <td id="T_5d4b2_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_5d4b2_row4_col6" class="data row4 col6" >1,022</td>
#       <td id="T_5d4b2_row4_col7" class="data row4 col7" >186,293</td>
#     </tr>
#     <tr>
#       <th id="T_5d4b2_level0_row5" class="row_heading level0 row5" >mdposit_mmb_node</th>
#       <td id="T_5d4b2_row5_col0" class="data row5 col0" >4,050</td>
#       <td id="T_5d4b2_row5_col1" class="data row5 col1" >2025-06-18</td>
#       <td id="T_5d4b2_row5_col2" class="data row5 col2" >2026-02-10</td>
#       <td id="T_5d4b2_row5_col3" class="data row5 col3" >4,050</td>
#       <td id="T_5d4b2_row5_col4" class="data row5 col4" >412,091</td>
#       <td id="T_5d4b2_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_5d4b2_row5_col6" class="data row5 col6" >15,124</td>
#       <td id="T_5d4b2_row5_col7" class="data row5 col7" >412,091</td>
#     </tr>
#     <tr>
#       <th id="T_5d4b2_level0_row6" class="row_heading level0 row6" >nomad</th>
#       <td id="T_5d4b2_row6_col0" class="data row6 col0" >16,119</td>
#       <td id="T_5d4b2_row6_col1" class="data row6 col1" >2021-05-13</td>
#       <td id="T_5d4b2_row6_col2" class="data row6 col2" >2026-02-05</td>
#       <td id="T_5d4b2_row6_col3" class="data row6 col3" >16,115</td>
#       <td id="T_5d4b2_row6_col4" class="data row6 col4" >555,990</td>
#       <td id="T_5d4b2_row6_col5" class="data row6 col5" >0</td>
#       <td id="T_5d4b2_row6_col6" class="data row6 col6" >2,189</td>
#       <td id="T_5d4b2_row6_col7" class="data row6 col7" >555,990</td>
#     </tr>
#     <tr>
#       <th id="T_5d4b2_level0_row7" class="row_heading level0 row7" >zenodo</th>
#       <td id="T_5d4b2_row7_col0" class="data row7 col0" >2,369</td>
#       <td id="T_5d4b2_row7_col1" class="data row7 col1" >2014-11-19</td>
#       <td id="T_5d4b2_row7_col2" class="data row7 col2" >2026-02-14</td>
#       <td id="T_5d4b2_row7_col3" class="data row7 col3" >2,370</td>
#       <td id="T_5d4b2_row7_col4" class="data row7 col4" >36,019</td>
#       <td id="T_5d4b2_row7_col5" class="data row7 col5" >4,893</td>
#       <td id="T_5d4b2_row7_col6" class="data row7 col6" >26,687</td>
#       <td id="T_5d4b2_row7_col7" class="data row7 col7" >506,320</td>
#     </tr>
#     <tr>
#       <th id="T_5d4b2_level0_row8" class="row_heading level0 row8" >total</th>
#       <td id="T_5d4b2_row8_col0" class="data row8 col0" >27,708</td>
#       <td id="T_5d4b2_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_5d4b2_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_5d4b2_row8_col3" class="data row8 col3" >27,307</td>
#       <td id="T_5d4b2_row8_col4" class="data row8 col4" >1,458,623</td>
#       <td id="T_5d4b2_row8_col5" class="data row8 col5" >11,758</td>
#       <td id="T_5d4b2_row8_col6" class="data row8 col6" >57,275</td>
#       <td id="T_5d4b2_row8_col7" class="data row8 col7" >2,144,433</td>
#     </tr>
#   </tbody>
# </table>

# %%
(files_df
 .loc[:, "file_type"]
 .value_counts()
 .head(n=20)
)
# Out:
# file_type
# jpg     337281
# bin     311724
# pdb     228081
# xtc     102582
# gro      95825
# mdp      84347
# itp      68084
# tpr      65840
# log      57951
# xvg      54466
# cpt      52170
# edr      51194
# out      45858
# dat      44047
#          40613
# traj     27219
# top      26269
# txt      23139
# xyz      21491
# npz      15509
# Name: count, dtype: int64

# %%
# Out:
#         dataset_repository_name dataset_id_in_repository  \
# 5                        zenodo                   259335
# 11                       zenodo                   259335
# 17                       zenodo                   259335
# 24                       zenodo                   259335
# 27                       zenodo                   259335
# ...                         ...                      ...
# 2144417                  gpcrmd                     2358
# 2144420                  gpcrmd                     2359
# 2144424                  gpcrmd                     2375
# 2144427                  gpcrmd                     2377
# 2144430                  gpcrmd                     2378
#
#                                dataset_url_in_repository           file_name  \
# 5                      https://zenodo.org/records/259335            md30.gro
# 11                     https://zenodo.org/records/259335            md20.gro
# 17                     https://zenodo.org/records/259335            md10.gro
# 24                     https://zenodo.org/records/259335         md0_370.gro
# 27                     https://zenodo.org/records/259335         md0_330.gro
# ...                                                  ...                 ...
# 2144417  https://www.gpcrmd.org/dynadb/dynamics/id/2358/  tmp_dyn_0_2714.pdb
# 2144420  https://www.gpcrmd.org/dynadb/dynamics/id/2359/  tmp_dyn_0_2716.pdb
# 2144424  https://www.gpcrmd.org/dynadb/dynamics/id/2375/  tmp_dyn_0_2733.pdb
# 2144427  https://www.gpcrmd.org/dynadb/dynamics/id/2377/  tmp_dyn_0_2735.pdb
# 2144430  https://www.gpcrmd.org/dynadb/dynamics/id/2378/  tmp_dyn_0_2737.pdb
#
#                                     file_url_in_repository  \
# 5        https://zenodo.org/api/records/259335/files/md...
# 11       https://zenodo.org/api/records/259335/files/md...
# 17       https://zenodo.org/api/records/259335/files/md...
# 24       https://zenodo.org/api/records/259335/files/md...
# 27       https://zenodo.org/api/records/259335/files/md...
# ...                                                    ...
# 2144417  https://www.gpcrmd.org/dynadb/files/Dynamics/d...
# 2144420  https://www.gpcrmd.org/dynadb/files/Dynamics/d...
# 2144424  https://www.gpcrmd.org/dynadb/files/Dynamics/d...
# 2144427  https://www.gpcrmd.org/dynadb/files/Dynamics/d...
# 2144430  https://www.gpcrmd.org/dynadb/files/Dynamics/d...
#
#          file_size_in_bytes                          file_md5  \
# 5                 4154274.0  97ebfe98a83452b76730591888dd8962
# 11                3970458.0  2012e2478f2e017a8b2c695836a9b4f7
# 17                3827490.0  4c9a0b7b4bc99bc43e1bf7e62a2bb3a4
# 24                3715157.0  829a3fe308c3261f28382edad4d67c29
# 27                3715157.0  4df63c860106a241167f8c0ab4265f45
# ...                     ...                               ...
# 2144417          17308077.0                              None
# 2144420            478830.0                              None
# 2144424            375957.0                              None
# 2144427           6342851.0                              None
# 2144430           6393648.0                              None
#
#         containing_archive_file_name file_type  \
# 5                               None       gro
# 11                              None       gro
# 17                              None       gro
# 24                              None       gro
# 27                              None       gro
# ...                              ...       ...
# 2144417                         None       pdb
# 2144420                         None       pdb
# 2144424                         None       pdb
# 2144427                         None       pdb
# 2144430                         None       pdb
#
#         file_size_with_human_readable_unit  _is_zip_file  \
# 5                                   4.2 MB         False
# 11                                  4.0 MB         False
# 17                                  3.8 MB         False
# 24                                  3.7 MB         False
# 27                                  3.7 MB         False
# ...                                    ...           ...
# 2144417                            17.3 MB         False
# 2144420                           478.8 KB         False
# 2144424                           376.0 KB         False
# 2144427                             6.3 MB         False
# 2144430                             6.4 MB         False
#
#          _size_not_from_zip_file  _is_not_from_zip_file
# 5                       0.004154                   True
# 11                      0.003970                   True
# 17                      0.003827                   True
# 24                      0.003715                   True
# 27                      0.003715                   True
# ...                          ...                    ...
# 2144417                 0.017308                   True
# 2144420                 0.000479                   True
# 2144424                 0.000376                   True
# 2144427                 0.006343                   True
# 2144430                 0.006394                   True
#
# [323906 rows x 13 columns]

# %%
file_types = ["pdb", "gro"]
tmp_files_df = (files_df
    .query("file_type in @file_types")
)
files_with_date_df = (
    pd.merge(
        tmp_files_df,
        datasets_df[["dataset_repository_name", "dataset_id_in_repository", "date_created"]],
        how="left",
        on=["dataset_repository_name", "dataset_id_in_repository"]
    )
)
files_with_date_df["year"] = pd.to_datetime(files_with_date_df["date_created"]).dt.year
years_df = (files_with_date_df
 .query("year != 2026")
 .groupby(["year", "dataset_repository_name"])
 .size().unstack()
)
years_df.style.format(thousands=",", precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_64ea3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset_repository_name</th>
#       <th id="T_64ea3_level0_col0" class="col_heading level0 col0" >figshare</th>
#       <th id="T_64ea3_level0_col1" class="col_heading level0 col1" >gpcrmd</th>
#       <th id="T_64ea3_level0_col2" class="col_heading level0 col2" >mdposit_cineca_node</th>
#       <th id="T_64ea3_level0_col3" class="col_heading level0 col3" >mdposit_inria_node</th>
#       <th id="T_64ea3_level0_col4" class="col_heading level0 col4" >mdposit_mmb_node</th>
#       <th id="T_64ea3_level0_col5" class="col_heading level0 col5" >nomad</th>
#       <th id="T_64ea3_level0_col6" class="col_heading level0 col6" >zenodo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64ea3_level0_row0" class="row_heading level0 row0" >2012.000000</th>
#       <td id="T_64ea3_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_64ea3_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_64ea3_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_64ea3_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_64ea3_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_64ea3_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_64ea3_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row1" class="row_heading level0 row1" >2013.000000</th>
#       <td id="T_64ea3_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_64ea3_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_64ea3_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_64ea3_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_64ea3_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_64ea3_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_64ea3_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row2" class="row_heading level0 row2" >2014.000000</th>
#       <td id="T_64ea3_row2_col0" class="data row2 col0" >63</td>
#       <td id="T_64ea3_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_64ea3_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_64ea3_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_64ea3_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_64ea3_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_64ea3_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row3" class="row_heading level0 row3" >2015.000000</th>
#       <td id="T_64ea3_row3_col0" class="data row3 col0" >157</td>
#       <td id="T_64ea3_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_64ea3_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_64ea3_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_64ea3_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_64ea3_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_64ea3_row3_col6" class="data row3 col6" >53</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row4" class="row_heading level0 row4" >2016.000000</th>
#       <td id="T_64ea3_row4_col0" class="data row4 col0" >899</td>
#       <td id="T_64ea3_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_64ea3_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_64ea3_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_64ea3_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_64ea3_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_64ea3_row4_col6" class="data row4 col6" >239</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row5" class="row_heading level0 row5" >2017.000000</th>
#       <td id="T_64ea3_row5_col0" class="data row5 col0" >250</td>
#       <td id="T_64ea3_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_64ea3_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_64ea3_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_64ea3_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_64ea3_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_64ea3_row5_col6" class="data row5 col6" >598</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row6" class="row_heading level0 row6" >2018.000000</th>
#       <td id="T_64ea3_row6_col0" class="data row6 col0" >128</td>
#       <td id="T_64ea3_row6_col1" class="data row6 col1" >155</td>
#       <td id="T_64ea3_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_64ea3_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_64ea3_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_64ea3_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_64ea3_row6_col6" class="data row6 col6" >225</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row7" class="row_heading level0 row7" >2019.000000</th>
#       <td id="T_64ea3_row7_col0" class="data row7 col0" >751</td>
#       <td id="T_64ea3_row7_col1" class="data row7 col1" >34</td>
#       <td id="T_64ea3_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_64ea3_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_64ea3_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_64ea3_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_64ea3_row7_col6" class="data row7 col6" >1,780</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row8" class="row_heading level0 row8" >2020.000000</th>
#       <td id="T_64ea3_row8_col0" class="data row8 col0" >808</td>
#       <td id="T_64ea3_row8_col1" class="data row8 col1" >14</td>
#       <td id="T_64ea3_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_64ea3_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_64ea3_row8_col4" class="data row8 col4" >nan</td>
#       <td id="T_64ea3_row8_col5" class="data row8 col5" >nan</td>
#       <td id="T_64ea3_row8_col6" class="data row8 col6" >3,076</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row9" class="row_heading level0 row9" >2021.000000</th>
#       <td id="T_64ea3_row9_col0" class="data row9 col0" >365</td>
#       <td id="T_64ea3_row9_col1" class="data row9 col1" >25</td>
#       <td id="T_64ea3_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_64ea3_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_64ea3_row9_col4" class="data row9 col4" >nan</td>
#       <td id="T_64ea3_row9_col5" class="data row9 col5" >nan</td>
#       <td id="T_64ea3_row9_col6" class="data row9 col6" >3,533</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row10" class="row_heading level0 row10" >2022.000000</th>
#       <td id="T_64ea3_row10_col0" class="data row10 col0" >1,343</td>
#       <td id="T_64ea3_row10_col1" class="data row10 col1" >28</td>
#       <td id="T_64ea3_row10_col2" class="data row10 col2" >nan</td>
#       <td id="T_64ea3_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_64ea3_row10_col4" class="data row10 col4" >nan</td>
#       <td id="T_64ea3_row10_col5" class="data row10 col5" >nan</td>
#       <td id="T_64ea3_row10_col6" class="data row10 col6" >5,053</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row11" class="row_heading level0 row11" >2023.000000</th>
#       <td id="T_64ea3_row11_col0" class="data row11 col0" >2,383</td>
#       <td id="T_64ea3_row11_col1" class="data row11 col1" >57</td>
#       <td id="T_64ea3_row11_col2" class="data row11 col2" >nan</td>
#       <td id="T_64ea3_row11_col3" class="data row11 col3" >nan</td>
#       <td id="T_64ea3_row11_col4" class="data row11 col4" >nan</td>
#       <td id="T_64ea3_row11_col5" class="data row11 col5" >49,653</td>
#       <td id="T_64ea3_row11_col6" class="data row11 col6" >8,831</td>
#     </tr>
#     <tr>
#       <th id="T_64ea3_level0_row12" cl

# %%
plt.rcParams.update({"font.size": 16})
fig, ax = plt.subplots(figsize=(12, 7))
data_repositories = [
    {"name": "zenodo", "offset": 0, "color": "darkorange"},
    {"name": "figshare", "offset": 0, "color": "red"},
    {"name": "gpcrmd", "offset": 0, "color": "limegreen"},
    {"name": "mdposit_mmb_node", "offset": 0, "color": "dodgerblue"},
    {"name": "mdposit_inria_node", "offset": 0, "color": "steelblue"},
    {"name": "mdposit_cineca_node", "offset": 0, "color": "deepskyblue"},
    {"name": "nomad", "offset": 0, "color": "magenta"},
]
for repo in data_repositories:
    tmp_df = years_df[repo["name"]].dropna()
    ax.scatter(tmp_df.index, tmp_df, label=repo["name"], color=repo["color"], s=80)
    ax.plot(tmp_df.index, tmp_df, ls="-", color=repo["color"], linewidth=2)
    ax.annotate(
        repo["name"],
        xy=(tmp_df.index[-1], tmp_df.iloc[-1]),
        xytext=(tmp_df.index[-1] + 0.75, tmp_df.iloc[-1] + repo["offset"]),
        textcoords="data",
        color=repo["color"],
        va="center",
        ha="left",
        arrowprops=dict(edgecolor=repo["color"], arrowstyle="-", linestyle=":", linewidth=1)
    )
ax.set_xlabel("Year", weight="bold")
ax.set_ylabel("Number of files", weight="bold")
ax.set_yscale("log")  # Convert y-axis to logarithmic scale
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

#filename = "number_of_files_per_years_per_data_repositories"
#plt.savefig(f"{filename}.png", dpi=300, bbox_inches="tight")
#plt.savefig(f"{filename}.svg", bbox_inches="tight")
